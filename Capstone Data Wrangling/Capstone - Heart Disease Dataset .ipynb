# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
col_names = ['age', 'sex', 'cp', 'rbp', 'scl', 'fbs', 'rer', 'mhra', 'eia', 'std', 'stss', 'fcv', 'tls', 'dhd']

# %%
data = pd.read_csv('processed.cleveland.data.csv', header=None, names=col_names)

# %%
print (data)
# Out:
#       age  sex   cp    rbp    scl  fbs  rer   mhra  eia  std  stss  fcv  tls  \
# 0    63.0  1.0  1.0  145.0  233.0  1.0  2.0  150.0  0.0  2.3   3.0  0.0  6.0
# 1    67.0  1.0  4.0  160.0  286.0  0.0  2.0  108.0  1.0  1.5   2.0  3.0  3.0
# 2    67.0  1.0  4.0  120.0  229.0  0.0  2.0  129.0  1.0  2.6   2.0  2.0  7.0
# 3    37.0  1.0  3.0  130.0  250.0  0.0  0.0  187.0  0.0  3.5   3.0  0.0  3.0
# 4    41.0  0.0  2.0  130.0  204.0  0.0  2.0  172.0  0.0  1.4   1.0  0.0  3.0
# 5    56.0  1.0  2.0  120.0  236.0  0.0  0.0  178.0  0.0  0.8   1.0  0.0  3.0
# 6    62.0  0.0  4.0  140.0  268.0  0.0  2.0  160.0  0.0  3.6   3.0  2.0  3.0
# 7    57.0  0.0  4.0  120.0  354.0  0.0  0.0  163.0  1.0  0.6   1.0  0.0  3.0
# 8    63.0  1.0  4.0  130.0  254.0  0.0  2.0  147.0  0.0  1.4   2.0  1.0  7.0
# 9    53.0  1.0  4.0  140.0  203.0  1.0  2.0  155.0  1.0  3.1   3.0  0.0  7.0
# 10   57.0  1.0  4.0  140.0  192.0  0.0  0.0  148.0  0.0  0.4   2.0  0.0  6.0
# ...

# %%
print(data.shape)
# Out:
# (303, 14)

# %%
data1 = pd.read_csv('processed.switzerland.data.csv', header=None, names=col_names)

# %%
print(data1.shape)
# Out:
# (123, 14)

# %%
data2 = pd.read_csv('processed.va.data.csv', header=None, names=col_names)

# %%
print (data2.shape)
# Out:
# (200, 14)

# %%
data3 = pd.read_csv('reprocessed.hungarian.data.csv', sep=" ", header=None, names=col_names)

# %%
print (data3.shape)
# Out:
# (295, 14)

# %%
dataset = (data.append([data1, data2, data3],sort=True))

# %%
print(dataset.shape)
# Out:
# (921, 14)

# %%
print(dataset.head())
# Out:
#     age   cp  dhd eia fbs  fcv mhra  rbp rer  scl  sex  std stss  tls
# 0  63.0  1.0  0.0   0   1  0.0  150  145   2  233  1.0  2.3    3  6.0
# 1  67.0  4.0  2.0   1   0  3.0  108  160   2  286  1.0  1.5    2  3.0
# 2  67.0  4.0  1.0   1   0  2.0  129  120   2  229  1.0  2.6    2  7.0
# 3  37.0  3.0  0.0   0   0  0.0  187  130   0  250  1.0  3.5    3  3.0
# 4  41.0  2.0  0.0   0   0  0.0  172  130   2  204  0.0  1.4    1  3.0

# %%
print(dataset.tail())
# Out:
#       age   cp  dhd  eia  fbs  fcv mhra  rbp  rer  scl  sex  std stss  tls
# 290  36.0  2.0  0.0    0    0   -9  180  120    0  166  1.0    0   -9   -9
# 291  48.0  3.0  0.0    0    0   -9  138  110    0  211  1.0    0   -9    6
# 292  47.0  2.0  0.0    0    0   -9  135  140    0  257  0.0    1    1   -9
# 293  53.0  4.0  0.0    0    0   -9  148  130    0  182  1.0    0   -9   -9
# 294   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %%
dataset.reset_index()
# Out:
#      index   age   cp  dhd  eia  fbs  fcv mhra  rbp  rer  scl  sex  std stss  \
# 0        0  63.0  1.0  0.0    0    1  0.0  150  145    2  233  1.0  2.3    3
# 1        1  67.0  4.0  2.0    1    0  3.0  108  160    2  286  1.0  1.5    2
# 2        2  67.0  4.0  1.0    1    0  2.0  129  120    2  229  1.0  2.6    2
# 3        3  37.0  3.0  0.0    0    0  0.0  187  130    0  250  1.0  3.5    3
# 4        4  41.0  2.0  0.0    0    0  0.0  172  130    2  204  0.0  1.4    1
# 5        5  56.0  2.0  0.0    0    0  0.0  178  120    0  236  1.0  0.8    1
# 6        6  62.0  4.0  3.0    0    0  2.0  160  140    2  268  0.0  3.6    3
# 7        7  57.0  4.0  0.0    1    0  0.0  163  120    0  354  0.0  0.6    1
# 8        8  63.0  4.0  2.0    0    0  1.0  147  130    2  254  1.0  1.4    2
# 9        9  53.0  4.0  1.0    1    1  0.0  155  140    2  203  1.0  3.1    3
# 10      10  57.0  4.0  0.0    0    0  0.0  148  140    0  192  1.0  0.4    2
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 921 entries, 0 to 294
# Data columns (total 14 columns):
# age     920 non-null float64
# cp      920 non-null float64
# dhd     920 non-null float64
# eia     920 non-null object
# fbs     920 non-null object
# fcv     920 non-null object
# mhra    920 non-null object
# rbp     920 non-null object
# rer     920 non-null object
# scl     920 non-null object
# sex     920 non-null float64
# std     920 non-null object
# stss    920 non-null object
# tls     920 non-null object
# dtypes: float64(4), object(10)
# memory usage: 107.9+ KB

# %%
dataset.isnull().values.any()
# Out:
# True

# %%
dataset.dropna(axis=0, how='any', inplace=True)

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset=dataset[dataset.eia != -9]

# %%
dataset=dataset[dataset.eia != '?']

# %%
dataset.eia.value_counts()
# Out:
# 0.0    408
# 1.0    188
# 1      149
# 0      120
# Name: eia, dtype: int64

# %%
dataset.eia
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
# 5      0
# 6      0
# 7      1
# 8      0
# 9      1
# 10     0
# 11     0
# 12     1
# 13     0
# 14     0
# 15     0
# 16     0
# 17     0
# 18     0
# 19     0
# 20     1
# 21     0
# 22     0
# 23     0
# 24     1
# 25     0
# 26     0
# 27     0
# 28     0
# 29     1
#       ..
# 263    1
# 264    0
# 265    1
# 266    0
# 267    1
# 268    0
# 269    1
# 270    0
# 271    0
# 272    0
# 273    1
# 274    0
# 275    0
# 276    0
# 277    0
# 278    1
# 279    1
# 280    0
# 281    0
# 282    0
# 283    1
# 284    0
# 285    0
# 286    0
# 287    0
# 288    0
# 290    0
# 291    0
# 292    0
# 293    0
# Name: eia, Length: 865, dtype: object

# %%
type(dataset.eia)
# Out:
# pandas.core.series.Series

# %%
dataset.eia=dataset.eia.astype(float)

# %%
dataset.plot(y='eia', kind='hist')
plt.xlabel('Exercise Induced Angina')
plt.show()

# %%
dataset.plot(y='age', kind='hist', bins=15)
plt.xlabel('Patient Age Distribution')
plt.show()

# %%
dataset.plot(y='age', kind='hist', bins=15, cumulative=True)
plt.xlabel('Patient Age Distribution')
plt.show()

# %%
dataset.rbp.value_counts()
# Out:
# 120.0    102
# 130.0     90
# 140.0     82
# 110.0     40
# 150.0     40
# 160.0     31
# 120       29
# 130       25
# 140       20
# 160       19
# 110       19
# 125.0     19
# 150       16
# 115       14
# 138.0     13
# 128.0     13
# 112.0     12
# 135.0     11
# 145.0     10
# 100.0     10
# 125       10
# 180.0      9
# 132.0      9
# 118.0      9
# 170.0      9
# 124.0      8
# 108.0      7
# 135        7
# 122.0      6
# 122        6
#         ...
# 102        1
# 92.0       1
# 172        1
# 114        1
# 80         1
# 185        1
# 165.0      1
# 127        1
# 146        1
# 158.0      1
# 156.0      1
# 154.0      1
# 172.0      1
# 174.0      1
# 190.0      1
# 192.0      1
# 129.0      1
# 123.0      1
# 117.0      1
# 98.0       1
# 114.0      1
# 113.0      1
# 156        1
# 164.0      1
# 165        1
# 106        1
# 96         1
# 104.0      1
# 101.0      1
# 190        1
# Name: rbp, Length: 103, dtype: int64

# %%
dataset=dataset[dataset.rbp != -9]
dataset=dataset[dataset.rbp != '?']
dataset.rbp=dataset.rbp.astype(float)

# %%
dataset=dataset[dataset != -9]
dataset=dataset[dataset != '?']
dataset=dataset.astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 861 entries, 0 to 293
# Data columns (total 14 columns):
# age     861 non-null float64
# cp      861 non-null float64
# dhd     861 non-null float64
# eia     861 non-null float64
# fbs     772 non-null float64
# fcv     310 non-null float64
# mhra    861 non-null float64
# rbp     861 non-null float64
# rer     859 non-null float64
# scl     834 non-null float64
# sex     861 non-null float64
# std     854 non-null float64
# stss    608 non-null float64
# tls     430 non-null float64
# dtypes: float64(14)
# memory usage: 100.9 KB

# %%
dataset.plot(x='age', y='rbp', kind='scatter')
plt.xlabel('Patient Age')
plt.ylabel('Resting Blood Pressure')
plt.show()

# %%
dataset.rbp[data.eia==1].plot.box()
plt.ylabel('Resting Blood Pressure')
plt.show()
